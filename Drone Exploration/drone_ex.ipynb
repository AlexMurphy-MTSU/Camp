# %%
'''
This exploration follows the example here: 
https://www.thepythoncode.com/article/extracting-image-metadata-in-python
'''

# %%
import pandas as pd
from PIL import Image
from PIL.ExifTags import TAGS, GPSTAGS

# %%
# read in image files

# %%
# initialise and open our file

# %%
# extract other basic metadata
info_dict = {
    "Filename": image.filename,
    "Image Size": image.size,
    "Image Height": image.height,
    "Image Width": image.width,
    "Image Format": image.format,
    "Image Mode": image.mode,
    "Image is Animated": getattr(image, "is_animated", False),
    "Frames in Image": getattr(image, "n_frames", 1)
}

for label,value in info_dict.items():
    print(f"{label:25}: {value}")
# Out:
# Filename                 : IMG_210420_164115_0098_NIR.TIF
# Image Size               : (1280, 960)
# Image Height             : 960
# Image Width              : 1280
# Image Format             : TIFF
# Image Mode               : I;16
# Image is Animated        : False
# Frames in Image          : 1

# %%
exifdata = image.getexif()
pre_df = {}
# iterating over all EXIF data fields
for tag_id in exifdata:
    # get the tag name, instead of human unreadable tag id
    tag = TAGS.get(tag_id, tag_id)
    data = exifdata.get(tag_id)
    # decode bytes 
    if isinstance(data, bytes):
        data = data.decode()
    print(f"{tag:25}: {data}")
    if tag in pre_df.keys():
        pre_df[tag].append(data)
    else:
        pre_df[tag] = [data]
# Out:
# ImageWidth               : 1280
# ImageLength              : 960
# BitsPerSample            : 16
# Compression              : 1
# PhotometricInterpretation: 1
# OriginalRawFileName      : IMG_210420_164115_0098_NIR.TIF
# ImageDescription         : 790 nm
# Make                     : Parrot
# Model                    : Sequoia
# StripOffsets             : 8
# Orientation              : 3
# SamplesPerPixel          : 1
# StripByteCounts          : 2457600
# MinSampleValue           : 0
# BlackLevelRepeatDim      : (2, 2)
# BlackLevel               : (5777, 5739, 5759, 5764)
# PlanarConfiguration      : 1
# GPSInfo                  : 2458434
# CameraSerialNumber       : PI040378AC7C002840
# Software                 : v1.4.1
# DateTime                 : 2021:04:20 16:41:15
# XMLPacket                : <?xpacket begin="﻿" id="W5M0MpCehiHzreSzNTczkc9d"?>
# <x:xmpmeta xmlns:x="adobe:ns:meta/">
#  <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
# <rdf:Description rdf:about=""
#  xmlns:Camera="http://pix4d.com/camera/1.0/"
#  Camera:RigName="Sequoia"
#  Camera:RigCameraIndex="3"
#  Camera:Yaw="-144.853577"
#  Camera:Pitch="-21.414253"
#  Camera:Roll="0.978734"
#  Camera:BandGain="1.000000"
#  Camera:SensorTemperature="59.285706"
#  Camera:LineReadoutTime="23076"
#  Camera:RigRelatives="-0.484620700433769,-0.198586487408599,-0.214554867684752"
#  Camera:PrincipalPoint="2.437384,1.815976"
#  Camera:ModelType="fisheye"
#  Camera:FisheyeAffineSymmetric="1"
#  Camera:FisheyeAffineMatrix="1669.910401893,0,0,1669.910401893"
#  Camera:FisheyePolynomial="0,1,0.012324377,-0.150885966"
#  Camera:GPSXYAccuracy="1.200667"
#  Camera:GPSZAccuracy="2.285000"
#  Camera:FlightUUID="BDA8508B83BB84BCF369EF13EBA518CA"
#  Camera:CaptureUUID="9C041E1F5D15DD472E7B0DE2E35057CB"
#  Camera:SunshineSerialNumber="PI040379BB7C002905"
#  Camera:IrradianceCalibrationMeasurement="0,600,43,22,1,600,1079,550,2,600,18092,9126,3,600,65535,65535"
#  Camera:CalibrationMeasurement="1,0.00411522633744856,527"
#  Camera:CalibrationPicture="0"
# ,3,600,65535,65535"alibrationMeasurementGolden="0,600,38,19
#  Camera:IrradianceSensitivitiesGolden="614.221848,312.698984"
#  Camera:IrradianceUnitScale="1.7873713395012918"
#  >
# <Camera:SensorModel>
# <rdf:Seq>
# </rdf:li>93773.4141438687,4933.317833559413,2814.512547151501
# </rdf:Seq>
# </Camera:SensorModel>
# <Camera:BandName>
# <rdf:Seq>
# <rdf:li>NIR</rdf:li>
# </rdf:Seq>
# </Camera:BandName>
# <Camera:CentralWavelength>
# <rdf:Seq>
# <rdf:li>790.000000</rdf:li>
# </rdf:Seq>
# </Camera:CentralWavelength>
# <Camera:WavelengthFWHM>
# <rdf:Seq>
# <rdf:li>40.000000</rdf:li>
# </rdf:Seq>
# </Camera:WavelengthFWHM>
# <Camera:BlackCurrent>
# <rdf:Seq>
# <rdf:li>76.000000</rdf:li>
# </rdf:Seq>
# </Camera:BlackCurrent>
# <Camera:VignettingPolynomial2DName>
# <rdf:Seq>
# <rdf:li>0,0,1,0,2,0,3,0,4,0,0,1,0,2,0,3,0,4,1,1,1,2,1,3,2,1,2,2,3,1</rdf:li>
# </rdf:Seq>
# </Camera:VignettingPolynomial2DName>
# <Camera:VignettingPolynomial2D>
# <rdf:Seq>
# <rdf:li>0.7239411186430155,1.1311700524213000,-2.1465616012418574,2.0582483727877405,-0.9340006436439909,0.4107712273511702,-0.5918269018234624,0.3445418925807091,-0.1897493658745087,-1.0085402236729353,0.9696705312289091,0.0137005349144394,1.1053255636437365,-1.0259708800145337,-0.0743617646146584</rdf:li>
# </rdf:Seq>
# </Camera:VignettingPolynomial2D>
# <Camera:InvalidPixel>
# <rdf:Seq>
# <rdf:li>574,310,655,104,772,132,435,213,574,310</rdf:li>
# </rdf:Seq>
# </Camera:InvalidPixel>
# <Camera:IrradianceList>
# ...
# </Camera:IrradianceList>
# </rdf:Description>
# </rdf:RDF>
# </x:xmpmeta>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <?xpacket end="w"?>
# ExifOffset               : 2457962
